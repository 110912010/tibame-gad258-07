# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 1. 讀取 CSV
df = pd.read_csv('winequality-red.csv')

correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# 設定畫布大小
plt.figure(figsize=(8, 6))

# 使用 regplot 畫出散佈圖並加上線性回歸線 (趨勢線)
sns.regplot(x='quality', y='total sulfur dioxide', data=df, scatter_kws={'alpha':0.3}, line_kws={'color':'red'})

plt.title('total sulfur dioxide vs Quality Correlation')
plt.xlabel('Quality')
plt.ylabel('total sulfur dioxide')
plt.show()

# %%
# 設定畫布大小
plt.figure(figsize=(8, 6))

# 使用 regplot 畫出散佈圖並加上線性回歸線 (趨勢線)
sns.regplot(x='quality', y='density', data=df, scatter_kws={'alpha':0.3}, line_kws={'color':'red'})

plt.title('Density vs Quality Correlation')
plt.xlabel('Quality')
plt.ylabel('Density')
plt.show()

# %%
# 設定畫布大小
plt.figure(figsize=(8, 6))

# 使用 regplot 畫出散佈圖並加上線性回歸線 (趨勢線)
sns.regplot(x='quality', y='pH', data=df, scatter_kws={'alpha':0.3}, line_kws={'color':'red'})

plt.title('pH vs Quality Correlation')
plt.xlabel('Quality')
plt.ylabel('pH')
plt.show()

# %%
# 設定畫布大小
plt.figure(figsize=(8, 6))

# 使用 regplot 畫出散佈圖並加上線性回歸線 (趨勢線)
sns.regplot(x='quality', y='sulphates', data=df, scatter_kws={'alpha':0.3}, line_kws={'color':'red'})

plt.title(' Sulphates vs Quality Correlation')
plt.xlabel('Quality')
plt.ylabel('Sulphates')
plt.show()

# %%
# 設定畫布大小
plt.figure(figsize=(8, 6))

# 使用 regplot 畫出散佈圖並加上線性回歸線 (趨勢線)
sns.regplot(x='quality', y='alcohol', data=df, scatter_kws={'alpha':0.3}, line_kws={'color':'red'})

plt.title('Alcohol vs Quality Correlation')
plt.xlabel('Quality')
plt.ylabel('Alcohol')
plt.show()
