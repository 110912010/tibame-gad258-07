# %%
# Tableau
# 紅酒
# https://public.tableau.com/views/winequality-red_17701836593060/sheet0?:language=zh-TW&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link
# 白酒
# https://public.tableau.com/views/winequality-white/sheet4?:language=zh-TW&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 讀取紅酒 CSV
df_red = pd.read_csv('winequality-red.csv', sep=';')

correlation_matrix = df_red.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# 讀取紅酒 CSV
df_white = pd.read_csv('winequality-white.csv', sep=';')

correlation_matrix = df_white.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# 挑選欄位
cols_to_plot = ['total sulfur dioxide', 'density', 'pH','sulphates', 'alcohol']

# 建立 3x2 的畫布
fig, axes = plt.subplots(3, 2, figsize=(12, 10))

# 將 3x2 的矩陣展開成一維，方便迴圈讀取
axes = axes.flatten()

for i, col in enumerate(cols_to_plot):
    sns.regplot(x='quality', y=col, data=df_red, ax=axes[i], 
                scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
    axes[i].set_title(f'{col} vs Quality')

plt.tight_layout()
plt.show()

# %%
# 挑選欄位
cols_to_plot = ['total sulfur dioxide', 'density', 'pH','sulphates', 'alcohol']

# 建立 3x2 的畫布
fig, axes = plt.subplots(3, 2, figsize=(12, 10))

# 將 3x2 的矩陣展開成一維，方便迴圈讀取
axes = axes.flatten()

for i, col in enumerate(cols_to_plot):
    sns.regplot(x='quality', y=col, data=df_white, ax=axes[i], 
                scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
    axes[i].set_title(f'{col} vs Quality')

plt.tight_layout()
plt.show()

# %%
# 讀取兩個檔案
df_red = pd.read_csv('winequality-red.csv', sep=';')
df_white = pd.read_csv('winequality-white.csv', sep=';')

# 新增一欄標記類型
df_red['type'] = 'red'
df_white['type'] = 'white'

# 垂直合併
df_wine = pd.concat([df_red, df_white], axis=0, ignore_index=True)

print(f"紅酒資料筆數: {len(df_red)}")
print(f"白酒資料筆數: {len(df_white)}")
print(f"合併後總筆數: {len(df_wine)}")
# Out:
# 紅酒資料筆數: 1599
# 白酒資料筆數: 4898
# 合併後總筆數: 6497

# %%
# # 設定畫布大小
# plt.figure(figsize=(8, 6))

# # 使用 regplot 畫出散佈圖並加上線性回歸線 (趨勢線)
# sns.regplot(x='quality', y='total sulfur dioxide', data=df_red, scatter_kws={'alpha':0.3}, line_kws={'color':'red'})

# plt.title('total sulfur dioxide vs Quality Correlation')
# plt.xlabel('Quality')
# plt.ylabel('total sulfur dioxide')
# plt.show()
